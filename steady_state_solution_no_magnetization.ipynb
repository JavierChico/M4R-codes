# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
alpha = 0.3
ReFr = 2
r = np.linspace(alpha, 1, 100)
def steady_state(r):
    return 1/2*(1/2*(alpha**2-r**2)+np.log(r/alpha))

# %%
plt.plot(r, ReFr*steady_state(r))
#plt.plot(r, (r-alpha)*ReFr/2*(1/alpha-1))
#plt.plot(r, (r-alpha)*ReFr/2*(1/alpha-1-(r-alpha)/2+0.5*(r-alpha)/alpha**2))
plt.grid()

# %%
alfa = .5
k = np.linspace(0,1, 10)
epsilon =
