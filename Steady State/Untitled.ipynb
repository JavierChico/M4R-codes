# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#B=0
B = 0
A = 10
eta = np.linspace(0,50,100)
z = A**(1/3)*(np.log(np.abs(eta**2+A**(1/3)*eta+A**(2/3)))/6-np.log(np.abs(eta-A**(1/3)))/3+np.arctan((2*eta+A**(1/3))/(np.sqrt(3)*A**(1/3)))/np.sqrt(3))-eta - B

# %%
plt.plot(z,eta)
